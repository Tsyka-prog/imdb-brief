# %%
from scraping import *
from data_cleaning import *
from dataviz import *

# %%
url = f'https://www.imdb.com/search/title/?groups=top_250&sort=user_rating,desc&start=1&ref_=adv_nxt'
pages = get_pages(url)
final_df = movies_scrap(pages)
final_df.to_pickle('analyse_imdb.pkl')

# %%
imdb = pd.read_pickle('analyse_imdb.pkl')

# %% [markdown]
# ## Existe-t-il des corrélations dans nos données numériques ?

# %%
matrix_correlation(imdb)

# %%
regplot_votes_rating(imdb)

# %% [markdown]
# ## Quelles sont les décennies ayant le plus de films dans le top 250 ?

# %%
add_decade(imdb)
total_by_decade(imdb)

# %% [markdown]
# ## Quelle est la moyenne des recettes par rapoport à la note ?

# %%
barplot_gross_rating(imdb)

# %% [markdown]
# ## Quels sont les genres de films dominants dans le top 250 ?

# %%
types_movies(imdb)
